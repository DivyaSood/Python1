# %%
from sklearn import linear_model
'''import csv
with open("HousepricesinCalifornia2.csv", 'rb') as f:
    alllines = csv.reader(f,delimiter=',')
    for row in alllines:
        print row'''
        
#example on using pyplot; nothing to do with above csv read portion        
import matplotlib.pyplot as plt
import numpy as np
tup1 = (1,2,3,4,5);
tup2 = (10, 4, 8, 20, 30);

regr = linear_model.LinearRegression()
regr.fit(tup2, tup1)


#x = np.random.randn(1000)
#y = np.random.randn(1000) + 5

# normal distribution center at x=0 and y=5
plt.scatter(tup1, tup2)
plt.plot(tup2, regr.predict(tup2), color='blue')
plt.show()
# Out:
# C:\Users\hello\AppData\Local\Enthought\Canopy32\User\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6fb1d223c05c> in <module>()
#      13
#      14 regr = linear_model.LinearRegression()
# ---> 15 regr.fit(tup2, tup1)
#      16
#      17
#
# C:\Users\hello\AppData\Local\Enthought\Canopy32\User\lib\site-packages\sklearn\linear_model\base.pyc in fit(self, X, y, sample_weight)
#     425         n_jobs_ = self.n_jobs
#     426         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# ...

# %%
import pandas as pd
 
table = pd.read_excel('exgrade.xlsx',
                      sheetname = 'exgrade',
                      header = 0,
                      index_col = 0,
                      parse_cols = "A, C, D",
                      convert_float = True)
 
print(table)

import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(10)
y = np.random.randn(10) + 5

# normal distribution center at x=0 and y=5
plt.hist2d(x, y, bins=40)
plt.show()
# Out:
#             wins  losses
# Serial No.
# 1              3       5
# 2              2       1
# 3              1       3
# 4              1       1
# 5              4       3
# 6              2       1
# 7              3       4
# 8              2       2
# 9              3       2
# 10             4       3

# %%
with open('HousepricesinCalifornia2.csv') as f:
    reader = csv.reader(f)
    reader.next()
    for row in reader:
        for (i,v) in enumerate(row):
            columns[i].append(v)
print(columns[2])
print(columns[4])
# Out:
# ['', '', '', '', '', '', 'Alameda', '$226,149', '$219,306', '$225,162', '$229,333', '$232,291', '$231,250', '$232,916', '$228,467', '$225,000', '$221,093', '$226,126', '$218,161', '$216,532', '$222,896', '$221,768', '$233,192', '$239,885', '$229,129', '$234,042', '$231,551', '$224,811', '$221,656', '$221,098', '$228,195', '$212,500', '$213,194', '$222,837', '$226,946', '$221,220', '$229,885', '$222,153', '$223,511', '$219,496', '$214,925', '$217,514', '$222,321', '$209,583', '$201,699', '$216,313', '$219,999', '$219,897', '$228,279', '$215,408', '$223,888', '$212,005', '$208,918', '$215,714', '$207,994', '$207,822', '$204,389', '$209,117', '$217,890', '$205,494', '$216,705', '$205,912', '$203,947', '$211,482', '$207,390', '$203,550', '$208,654', '$194,528', '$199,258', '$198,888', '$204,610', '$209,335', '$214,090', '$212,316', '$211,904', '$210,893', '$207,414', '$206,743', '$204,362', '$201,739', '$205,250', '$208,046', '$210,130', '$213,709', '$213,414', '$222,612', '$218,452', '$
# ...

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
lm=linear_model.LinearRegression()
lst=[]
lst1=[]
input_file=csv.DictReader(open("exgrade.csv"))
for line in input_file:
    lst.append(line['A'])
    lst1.append(line['B'])
    print line['A']
print lst
print lst1
x= np.asarray(lst)
y= np.asarray(lst1)

print x
print y
plt.scatter(lst1,lst, color='green',background='yellow')
plt.show()
plt.plot(y, x)
# Out:
# 16
# 18
# 20
# 11
# 19
# 14
# 15
# 13
# 12
# 17
# ['16', '18', '20', '11', '19', '14', '15', '13', '12', '17']
# ['3', '2', '1', '1', '4', '2', '3', '2', '3', '4']
# ['16' '18' '20' '11' '19' '14' '15' '13' '12' '17']
# ['3' '2' '1' '1' '4' '2' '3' '2' '3' '4']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4544b1e160c3> in <module>()
#      18 print x
#      19 print y
# ---> 20 plt.scatter(lst1,lst, color='green',background='yellow')
#      21 plt.show()
#      22 plt.plot(y, x)
#
# C:\Users\hello\AppData\Local\Enthought\Canopy32\User\lib\site-packages\matplotlib\pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3249                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3250                          linewidths=linewidths, verts=verts,
# ...

# %%
import pandas as pd
import numpy as np

COLUMN_SEPARATOR = '  '
housing_data = pd.DataFrame.from_csv('exgrade.csv', sep=COLUMN_SEPARATOR, header=None)

#AREA_INDEX = 4
SELLING_PRICE_INDEX = 13
x = housing_data[AREA_INDEX]
y = housing_data[SELLING_PRICE_INDEX]
regression = np.polyfit(x, y, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-b69b5bd26314> in <module>()
#       7 #AREA_INDEX = 4
#       8 SELLING_PRICE_INDEX = 13
# ----> 9 x = housing_data[AREA_INDEX]
#      10 y = housing_data[SELLING_PRICE_INDEX]
#      11 regression = np.polyfit(x, y, 1)
#
# C:\Users\hello\AppData\Local\Enthought\Canopy32\User\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# C:\Users\hello\AppData\Local\Enthought\Canopy32\User\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
# ...

# %%
dict1=dict['divya'='himanshu']
print dict1
# Out:
#   File "<ipython-input-10-16c6fe5b9990>", line 1
#     dict1=dict['divya'='himanshu']
#                       ^
# SyntaxError: invalid syntax

# %%
import csv
input_file = csv.DictReader(open("HousepricesinCalifornia2.csv"))
for row in input_file:
    print row
# Out:
# {'': '', 'Median Price (existing single-family detached homes only) ': '*Note'}
# {'': '', 'Median Price (existing single-family detached homes only) ': ''}
# {'': '', 'Median Price (existing single-family detached homes only) ': ''}
# {'': '', 'Median Price (existing single-family detached homes only) ': ''}
# {'': '', 'Median Price (existing single-family detached homes only) ': ''}
# {'': '', 'Median Price (existing single-family detached homes only) ': ''}
# {'': '', 'Median Price (existing single-family detached homes only) ': 'Mon-Yr'}
# {'': '', 'Median Price (existing single-family detached homes only) ': 'Jan-90'}
# {'': '', 'Median Price (existing single-family detached homes only) ': 'Feb-90'}
# {'': '', 'Median Price (existing single-family detached homes only) ': 'Mar-90'}
# {'': '', 'Median Price (existing single-family detached homes only) ': 'Apr-90'}
# {'': '', 'Median Price (existing single-family detached homes only) ': 'May-90'}
# ...

# %%
import xlrd
wb = xlrd.open_workbook('HousepricesinCalifornia.xls')
print wb.sheet_names()
# Out:
# [u'Median Price']

# %%
ws = wb.sheet_by_name('Median Price')
print ws.nrows
# Out:
# 326

# %%
print ws.row(10)
#print ws.row(0)[10]
# Out:
# [xldate:32933.0, number:194856.0, number:225162.0, text:u'NA', number:100000.0, text:u'NA', text:u'NA', text:u'NA', text:u'NA', number:83888.5, text:u'NA', number:88888.0, number:87758.0, text:u'NA', text:u'NA', number:208134.8627487598, text:u'NA', number:358571.0, text:u'NA', number:111428.0, number:85909.0, number:230555.0, number:180000.0, text:u'NA', number:242312.4974534361, number:179470.0, text:u'NA', number:135835.1773552384, number:127500.0, text:u'NA', number:127017.0, number:183701.0, number:290151.0, number:117692.0, number:216010.03634151677, text:u'NA', number:253300.99191284712, number:275500.0, number:260577.0, text:u'NA', text:u'NA', text:u'NA', number:178823.0, text:u'NA', empty:u'', text:u'NA', number:84210.1052631579, text:u'NA', number:240320.0, text:u'NA', text:u'NA', empty:u'', number:209286.09262214752, number:235336.50149607597, text:u'NA']

# %%
#test code to understand linear regression more
#source code:  http://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html

# Code source: Jaques Grobler
# License: BSD 3 clause


import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

# Load the diabetes dataset
diabetes = datasets.load_diabetes()

ds = Dataset(diabetes)
ds.shape


# Use only one feature
diabetes_X = diabetes.data[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((regr.predict(diabetes_X_test) - diabetes_y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(diabetes_X_test, diabetes_y_test))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, regr.predict(diabetes_X_test), color='blue',
         linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ff093be27828> in <module>()
#      13 diabetes = datasets.load_diabetes()
#      14
# ---> 15 ds = Dataset(diabetes)
#      16 ds.shape
#      17
#
# NameError: name 'Dataset' is not defined
